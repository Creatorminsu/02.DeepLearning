# %% [markdown]
# # VGG Net 응용

# %%
from tensorflow.keras.applications.vgg16 import VGG16, decode_predictions

# %%
vgg16 = VGG16()
vgg16.summary()

# %%
from tensorflow.keras.applications.vgg19 import VGG19
vgg19 = VGG19()
vgg19.summary()

# %%
import numpy as np
from PIL import Image
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-84fbac18-4d3a-4348-a5ce-921cb41fcb11" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84fbac18-4d3a-4348-a5ce-921cb41fcb11">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat3.jfif to cat3.jfif

# %%
import matplotlib.pyplot as plt

img = Image.open('cat3.jfif').resize((224,224))
plt.imshow(img), plt.axis('off');

# %%
img = np.array(img.resize((224, 224)))
img.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# - 이미지 예측

# %%
yhat = vgg16.predict(np.array(img).reshape(-1,224,224,3))
label = decode_predictions(yhat)
yhat.shape, label
# Out:
# ((1, 1000),
#  [[('n02124075', 'Egyptian_cat', 0.58085394),
#    ('n02123045', 'tabby', 0.33690035),
#    ('n02123159', 'tiger_cat', 0.080482274),
#    ('n02127052', 'lynx', 0.00047275427),
#    ('n04040759', 'radiator', 0.00023365744)]])

# %%
label[0][0][1], label[0][0][2]
# Out:
# ('Egyptian_cat', 0.58085394)

# %%
yhat = vgg19.predict(np.array(img).reshape(-1,224,224,3))
label = decode_predictions(yhat)
label[0][0][1], label[0][0][2]
# Out:
# ('tabby', 0.7266756)

# %% [markdown]
# - 이미지를 224 x 224 사이즈로 자르기

# %%
img = Image.open('cat3.jfif')
h, w, c = np.array(img).shape
h, w
# Out:
# (182, 277)

# %%
if h > w:
    width, height = 224, (h * 224) // w
else:
    width, height = (w * 224) // h, 224
height, width
# Out:
# (224, 340)

# %%
new_img = np.array(img.resize((width, height)))
new_img.shape
# Out:
# (224, 340, 3)

# %%
plt.imshow(new_img);

# %%
diff = abs(width - height) // 2
if width > height: 
    final_img = new_img[:, diff:diff+224, :] 
else:
    final_img = new_img[diff:diff+224,:,:]
final_img.shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(final_img);

# %%
IMAGE_SIZE = 224

def center_image(img): 
    h, w, _ = np.array(img).shape
    if h > w:
        width, height = IMAGE_SIZE, (h * IMAGE_SIZE) // w
    else:
        width, height = (w * IMAGE_SIZE) // h, IMAGE_SIZE
    
    new_img = np.array(img.resize((width, height)))
    
    diff = abs(width - height) // 2
    if width > height: 
        final_img = new_img[:, diff:diff+IMAGE_SIZE, :] 
    else:
        final_img = new_img[diff:diff+IMAGE_SIZE,:,:]
    
    return final_img

# %%
img = Image.open('cat3.jfif')
img2 = center_image(img)
plt.imshow(img2);

# %%
yhat = vgg16.predict(np.array(img2).reshape(-1,224,224,3))
label = decode_predictions(yhat)
label[0][0][1], label[0][0][2]
# Out:
# ('tabby', 0.5744169)

# %%
yhat = vgg16.predict(np.array(img2).reshape(-1,224,224,3))
label = decode_predictions(yhat)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-732941639314> in <module>()
#       1 yhat = vgg16.predict(np.array(img2).reshape(-1,224,224,3))
#       2 label = decode_predictions(yhat)
# ----> 3 label.head()
#
# AttributeError: 'list' object has no attribute 'head'
